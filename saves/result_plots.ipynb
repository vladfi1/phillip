# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

saves = os.listdir('.')
saves.sort(key=os.path.getmtime)
saves.reverse()
saves = [save for save in saves if os.path.isdir(save)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

os.system('rsync -avP "wwhitney@openmind7.mit.edu:/om/user/wwhitney/smash-player/saves/ActorCritic/rewards.log" ./ac_rewards.log')
reward_log = 'ac_rewards.log'
# reward_log = 'simpleDQN' + '/rewards.log'
with open(reward_log, 'r') as f:
    scores = [float(score.strip()) for score in f.readlines()]
# sns.regplot(np.array(range(len(scores[:53]))), np.array(scores[:53]))
score_array = np.array(scores)
sns.regplot(np.array(range(len(scores))), score_array)
print(np.mean(score_array[-200:]))
# Out:
# 0.000618636995827

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

os.system('rsync -avP "wwhitney@openmind7.mit.edu:/om/user/wwhitney/smash-player/saves/DQN/rewards.log" ./dqn_rewards.log')
reward_log = 'dqn_rewards.log'
# reward_log = 'simpleDQN' + '/rewards.log'
with open(reward_log, 'r') as f:
    scores = [float(score.strip()) for score in f.readlines()]
# sns.regplot(np.array(range(len(scores[:53]))), np.array(scores[:53]))
score_array = np.array(scores)
sns.regplot(np.array(range(len(scores))), score_array)
print(np.mean(score_array[-200:]))
# Out:
# -0.00113059805285

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

os.system('rsync -avP "wwhitney@openmind7.mit.edu:/om/user/vladfi1/phillip/saves/DQN/rewards.log" ./old_dqn_rewards.log')
reward_log = 'old_dqn_rewards.log'
# reward_log = 'simpleDQN' + '/rewards.log'
with open(reward_log, 'r') as f:
    scores = [float(score.strip()) for score in f.readlines()]
# sns.regplot(np.array(range(len(scores[:53]))), np.array(scores[:53]))
score_array = np.array(scores)
sns.regplot(np.array(range(len(scores))), score_array)
print(np.mean(score_array[-200:]))
# Out:
# -0.00201036161335
